# %%
from skimage import feature,color
import PIL.Image as Image
import os
import numpy as np
import matplotlib.pyplot as plt

# %%
f, e = os.path.splitext('D:\Documents\Active Subjects\Halftoning\lion_art_colorful_122044_3840x2160.jpg')
outfile = "%s%s%s" % (f, '_kjsedbfkeahbf', e)
    
im = Image.open('D:\Documents\Active Subjects\Halftoning\lion_art_colorful_122044_3840x2160.jpg')
#print(color.rgb2gray(np.array(im)))
edges = feature.canny(color.rgb2gray(np.array(im)))
plt.imshow(edges)
plt.show()
